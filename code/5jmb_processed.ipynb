# %%
# !git clone https://github.com/THGLab/int2cart.git
# Out:
# fatal: destination path 'int2cart' already exists and is not an empty directory.

# %%
# !cd /content/int2cart && pip install -e .
# Out:
# Obtaining file:///content/int2cart
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 13.6 MB/s eta 0:00:00
# ...
#   Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...
#   Using cached sympy-1.12.1-py3-none-any.whl (5.7 MB)
# ...
#   Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# ...
#   Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# ...
#   Using cached fsspec-2024.6.0-py3-none-any.whl (176 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
# !pip install git+https://github.com/THGLab/sidechainnet.git
# Out:
# ...
#   Cloning https://github.com/THGLab/sidechainnet.git to /tmp/pip-req-build-41ycuf26
#   Running command git clone --filter=blob:none --quiet https://github.com/THGLab/sidechainnet.git /tmp/pip-req-build-41ycuf26
#   Resolved https://github.com/THGLab/sidechainnet.git to commit e6f4f6a30ad4e202db3afb28e4d958937cb57135
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install --upgrade git+https://github.com/JerryJohnsonLee/pdbtools.git
# Out:
# ...
#   Cloning https://github.com/JerryJohnsonLee/pdbtools.git to /tmp/pip-req-build-_p8l7wor
#   Running command git clone --filter=blob:none --quiet https://github.com/JerryJohnsonLee/pdbtools.git /tmp/pip-req-build-_p8l7wor
#   Resolved https://github.com/JerryJohnsonLee/pdbtools.git to commit eebc7873c8f1d84de5b7d9d4294fd3c9e19ac5c8
#   Preparing metadata (setup.py) ... done

# %%
# !git clone https://github.com/JerryJohnsonLee/pdbtools.git
# Out:
# WARNING: Skipping pdbtools as it is not installed.

# %%
# !sudo cp -r /content/pdbtools/pdbtools/helper /usr/local/lib/python3.10/dist-packages/pdbtools

# %%
# !sudo cp -r /content/pdbtools/pdbtools/charmm /usr/local/lib/python3.10/dist-packages/pdbtools

# %%
# !sudo cp -r /content/pdbtools/pdbtools/data /usr/local/lib/python3.10/dist-packages/pdbtools

# %%
# !sudo cp -r /content/pdbtools/pdbtools/development /usr/local/lib/python3.10/dist-packages/pdbtools

# %%
# !pip install tensorrt

# %%
# !dpkg -l | grep nvinfer

# %%
# !export LD_LIBRARY_PATH=/usr/local/cuda/lib64:/usr/local/TensorRT/lib
# !export PATH=$PATH:/usr/local/cuda/bin
# !pip install --upgrade tensorflow
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 92.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 90.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 94.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 73.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 39.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 2024-06-23 16:10:01.731686: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# !dpkg -l | grep nvidia
# !sudo apt-get update
# !sudo apt-get install -y nvidia-driver-470
# !sudo apt-get install -y python3-libnvinfer-dev
# !sudo apt-get install -y python3-libnvinfer
import os
os.environ['LD_LIBRARY_PATH'] += ':/usr/lib/x86_64-linux-gnu/'
# Out:
# ii  nvidia-opencl-dev:amd64                   11.5.1-1ubuntu1                         amd64        NVIDIA OpenCL development files
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# ...

# %%
# !sudo apt-get install -y nvidia-cuda-toolkit
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   dctrl-tools dkms keyboard-configuration libjansson4 libnvidia-cfg1-470
#   libnvidia-common-470 libnvidia-egl-wayland1 libnvidia-extra-470
#   libnvidia-fbc1-470 libnvidia-gl-470 libnvidia-ifr1-470 libxcvt0 libxfont2
#   nvidia-dkms-470 nvidia-kernel-common-470 nvidia-kernel-source-470
#   nvidia-prime nvidia-settings python3-xkit screen-resolution-extra
#   systemd-hwe-hwdb udev x11-xkb-utils xcvt xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xserver-xorg-core xserver-xorg-video-nvidia-470
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libaccinj64-11.5 libatk-wrapper-java
#   libatk-wrapper-java-jni libbabeltrace1 libcub-dev libcublas11 libcublaslt11
# ...

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
from tensorflow.python.compiler.tensorrt import trt_convert as trt
# Out:
# Num GPUs Available:  1

# %%
import tensorflow as tf

# Check TensorFlow version
print("TensorFlow version:", tf.__version__)

# Verify if TensorRT is integrated
from tensorflow.python.compiler.tensorrt import trt_convert as trt

print("TensorRT version:", trt.trt_utils._pywrap_py_utils.get_linked_tensorrt_version())
# Out:
# TensorFlow version: 2.16.1
# TensorRT version: (8, 6, 1)

# %%
import tensorrt as trt
print(trt.__version__)
# Out:
# 10.1.0

# %%
# !export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/local/tensorrt/lib

# %%
import os
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda/lib64:/usr/local/tensorrt/lib'  # Example paths, adjust as necessary

# %%
# !python /content/int2cart/run_scripts/predict.py --from_pdb /content/int2cart/example/5jmb.pdb --build -d cuda
# Out:
# 2024-06-23 16:32:00.703678: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# ## error torch.cross(z_hat, x_hat) add ```,dim=0``` to that file's errors. ``torch.cross(z_hat, x_hat,dim=0)``

# %% [markdown]
# # run !python /content/int2cart/run_scripts/predict.py --from_pdb /content/int2cart/example/5jmb.pdb --build -d cuda when succeed get `/content/int2cart/example/5jmb_processed.pdb` and `/content/int2cart/example/5jmb_processed_geom.csv` `**Don't care Warning:**` just Warning it's not an error

# %%
# !pip install pyrosettacolabsetup
import pyrosettacolabsetup; pyrosettacolabsetup.install_pyrosetta()
import pyrosetta; pyrosetta.init()
# Out:
# ...
# Mounted at /content/google_drive
#
# Note that USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE.
# See https://github.com/RosettaCommons/rosetta/blob/main/LICENSE.md or email license@uw.edu for details.
#
# Looking for compatible PyRosetta wheel file at google-drive/PyRosetta/colab.bin//wheels...
# ...
# --2024-06-23 16:49:00--  https://west.rosettacommons.org/pyrosetta/release/release/PyRosetta4.MinSizeRel.python310.ubuntu.wheel/.latest
# Resolving west.rosettacommons.org (west.rosettacommons.org)... 128.95.160.153, 2607:4000:406::160:153
#
# HTTP request sent, awaiting response... 302 Found
# Location: https://west.rosettacommons.org/pyrosetta/release/release/PyRosetta4.MinSizeRel.python310.ubuntu.wheel/pyrosetta-2024.19+release.a34b73c40f-cp310-cp310-linux_x86_64.whl [following]
# ...

# %%
from int2cart.rosetta.int2cart_mover import Int2CartMover
from pyrosetta import *
init()
import sys
sys.path.append('/content/int2cart/rosetta')
pose = pose_from_pdb("/content/int2cart/example/5jmb.pdb")
mover = Int2CartMover(pose.sequence(), device="cpu")
mover.apply(pose)
pose.dump_pdb("/content/int2cart/example/pose_after_int2cart_move.pdb")
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2024 [Rosetta PyRosetta4.MinSizeRel.python310.ubuntu 2024.19+release.a34b73c40fe9c61558d566d6a63f803cfb15a4fc 2024-05-02T16:22:03] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# ...
